# %% [markdown]
# # Lab 03 - Linear Discrimination
# ## Mehmet Gönen
# ### October 27, 2023

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats

def safelog(x):
    return(np.log(x + 1e-100))

# %% [markdown]
# ## Parameters

# %%
np.random.seed(421)
# mean parameters
class_means = np.array([[+1.5, +1.5],
                        [-1.5, -1.5]])
# covariance parameters
class_covariances = np.array([[[+1.6, +1.2], 
                               [+1.2, +1.6]],
                              [[+1.6, -1.2], 
                               [-1.2, +1.6]]])
# sample sizes
class_sizes = np.array([120, 180])

# %% [markdown]
# ## Data Generation

# %%
# generate random samples
points1 = np.random.multivariate_normal(mean = class_means[0, :],
                                        cov = class_covariances[0, :, :],
                                        size = class_sizes[0])
points2 = np.random.multivariate_normal(mean = class_means[1, :],
                                        cov = class_covariances[1, :, :],
                                        size = class_sizes[1])
X = np.vstack((points1, points2))

# generate corresponding labels
y = np.concatenate((np.repeat(1, class_sizes[0]), np.repeat(0, class_sizes[1])))

# %%
print(points1)
# Out:
# [[ 0.03844171  0.58072421]
#  [ 1.85037968  1.69322823]
#  [ 0.45117057 -0.2867786 ]
#  [ 2.80671102  2.58087749]
#  [ 1.02082749  0.18233503]
#  [ 2.59042311  3.37994875]
#  [ 0.57093839  1.69417762]
#  [ 2.01086754  1.2248023 ]
#  [ 0.06540099  0.27748694]
#  [ 0.02474338  0.75220421]
#  [ 2.65473045  2.24103988]
#  [ 2.82723101  2.34796953]
#  [ 1.08854009  0.78302343]
#  [ 1.27261802  1.62620649]
#  [ 1.69077524  2.94039381]
#  [ 1.85037643  1.21044807]
#  [ 2.08606081  1.7899857 ]
#  [-2.15537801 -0.80082024]
#  [ 1.64193403  0.49127196]
#  [ 0.71269818  1.42025648]
#  [ 1.22997141 -0.18504119]
#  [ 1.4801059   0.6181212 ]
#  [ 2.46883606  1.68247877]
#  [ 2.79196611  2.45572006]
#  [ 1.98405979  1.90955569]
#  [-0.30161549  0.22622113]
#  [ 0.54684115  1.32189464]
#  [ 3.24205598  3.02903673]
#  [ 2.97972667  2.28493054]
#  [ 1.62126927  1.70478418]
#  [ 3.6122535   2.66013621]
#  [-0.03288072 -0.11306984]
#  [ 3.36643103  3.84378508]
#  [ 2.20392423  1.85775239]
#  [-0.99780364  0.67641258]
#  [ 1.44304421  1.01368395]
#  [ 1.16893288  0.03345489]
#  [-0.151311    1.38886033]
#  [ 1.57210933  0.25141276]
#  [ 1.12763436  1.92088593]
#  [ 4.1614179   4.24017604]
#  [-0.33037118  0.98750013]
#  [ 0.37700295 -0.12336499]
#  [-0.32300389 -0.69787013]
#  [ 3.21835208  1.91189776]
#  [ 2.54072729  2.15397664]
#  [ 1.50071597  2.35916718]
#  [ 2.79287992  3.29370282]
#  [ 0.85333117  0.82355694]
#  [ 2.22784305  2.89771283]
#  [ 0.92672715  2.12690504]
#  [ 0.164423   -0.4792375 ]
#  [ 3.16081986  4.02104822]
#  [ 1.41942125  1.46684233]
#  [ 0.39279995  0.26613581]
#  [-0.94449243 -0.58789357]
#  [ 1.73810731  1.40007172]
#  [-1.01613828  1.06851371]
#  [ 2.67858573  2.61813833]
#  [ 0.55971953  1.45771562]
#  [ 1.18753753  1.64898393]
#  [ 0.18590826  1.10697101]
#  [ 1.98728256  0.95184049]
#  [ 2.68647678  2.92211821]
#  [-0.88933854  1.1804049 ]
#  [-0.50230915  0.58771624]
#  [ 0.9121835   0.96067802]
#  [ 1.37339628  2.41609948]
#  [ 2.18939028  2.1836747 ]
#  [ 3.29115693  3.7829503 ]
#  [ 1.11197749  1.16382514]
#  [ 1.16678265  1.89283708]
#  [ 1.22310465  0.6328215 ]
#  [ 2.34442231  2.25652532]
#  [ 3.11039178  2.35518746]
#  [ 0.51324161  0.32989151]
#  [ 2.11667534  2.02584793]
#  [ 3.00835378  1.23586029]
#  [ 1.58822808  0.94373306]
#  [ 2.67224487  1.72083894]
#  [ 1.91688882  2.41529312]
#  [ 1.22981942  0.46883466]
#  [-0.57977118  0.63675282]
#  [ 0.27094478  1.42414158]
#  [ 3.0138348   3.15437574]
#  [ 0.39882638  0.73497077]
#  [ 0.89355366  0.50848663]
#  [ 0.60581396  1.17580593]
#  [ 1.52080836  1.04849907]
#  [ 0.79774287  2.36289999]
#  [ 2.10021219  1.63788769]
#  [-0.18618445 -0.50268733]
#  [ 4.01096102  2.37108087]
#  [ 1.81280343  3.18381378]
#  [ 1.87329584  0.21385902]
#  [ 2.80857706  3.15542541]
#  [-1.31590151 -1.63649965]
#  [ 0.4972848   1.31969141]
#  [ 1.49576648  1.27729885]
#  [ 0.65853768  0.93758381]
#  [ 1.84182911  1.63407908]
#  [ 0.70645942  0.53021267]
#  [ 0.92087702 -0.05590252]
#  [ 0.74260849  1.16195478]
#  [ 3.11097204  2.44069913]
#  [ 1.71619175  2.57792935]
#  [ 2.20412342  2.23017043]
#  [ 2.43871302  1.91896298]
#  [ 1.87081598  3.26812905]
#  [ 3.113637    3.19460577]
#  [ 1.92714529  3.3432112 ]
#  [ 1.86752521  1.14310348]
#  [ 1.49289339  1.98391373]
#  [ 1.63345875  1.72182432]
#  [-1.63615013  0.13348297]
#  [ 1.45335114  2.10390695]
#  [ 2.1460919   2.44846368]
#  [ 1.19260538  1.17938471]
#  [ 1.97884997  1.99966232]
#  [ 2.58890426  2.90546122]]

# %% [markdown]
# ## Exporting Data

# %%
# write data to a file
np.savetxt("lab03_data_set.csv", np.hstack((X, y[:, None])), fmt = "%f,%f,%d")

# %% [markdown]
# ## Plotting Data

# %%
x1_interval = np.linspace(-5, +5, 501)
x2_interval = np.linspace(-5, +5, 501)
x1_grid, x2_grid = np.meshgrid(x1_interval, x2_interval)
X_grid = np.vstack((x1_grid.flatten(), x2_grid.flatten())).T

D1 = stats.multivariate_normal.pdf(X_grid, mean = class_means[0, :],
                                   cov = class_covariances[0, :, :])
D1 = D1.reshape((len(x1_interval), len(x2_interval)))
D2 = stats.multivariate_normal.pdf(X_grid, mean = class_means[1, :],
                                   cov = class_covariances[1, :, :])
D2 = D2.reshape((len(x1_interval), len(x2_interval)))

# plot data points generated
plt.figure(figsize = (8, 8))
plt.plot(points1[:, 0], points1[:, 1], "r.", markersize = 10)
plt.plot(points2[:, 0], points2[:, 1], "b.", markersize = 10)
plt.contour(x1_grid, x2_grid, D1, levels = [0.03, 0.06, 0.09, 0.12],
            colors = "r", linestyles = "dashed")
plt.contour(x1_grid, x2_grid, D2, levels = [0.03, 0.06, 0.09, 0.12],
            colors = "b", linestyles = "dashed")
plt.xlim((-5, +5))
plt.ylim((-5, +5))
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.show()

# %% [markdown]
# ## Importing Data

# %%
# read data into memory
data_set = np.genfromtxt("lab03_data_set.csv", delimiter = ",")

# get number of samples
N = data_set.shape[0]
# get number of features
D = data_set.shape[1] - 1

# get X and y values
X = data_set[:, 0:D]
y_truth = data_set[:, D:(D + 1)].astype(int)

# %% [markdown]
# ## Sigmoid Function

# %% [markdown]
# $\textrm{sigmoid}(\boldsymbol{w}^{\top} \boldsymbol{x} + w_{0}) = \dfrac{1}{1 + \exp\left[-(\boldsymbol{w}^{\top} \boldsymbol{x} + w_{0})\right]}$

# %%
# define the sigmoid function
def sigmoid(X, w, w0):
    return(1 / (1 + np.exp(-(np.matmul(X, w) + w0))))

# %%
draw_seq = np.linspace(-10, +10, 2001)
plt.figure(figsize = (8, 4))
plt.plot(draw_seq[draw_seq < 0], (draw_seq[draw_seq < 0] > 0), "b-") #step function
plt.plot([0, 0], [0, 1], "b-") #step function
plt.plot(draw_seq[draw_seq > 0], (draw_seq[draw_seq > 0] > 0), "b-", label = "step function") #step function
plt.plot(draw_seq, 1 / (1 + np.exp(-draw_seq)), "r-", label = "sigmoid function") #sigmoid function
plt.xlabel("$x$")
plt.legend()
plt.show()

# %% [markdown]
# ## Gradient Functions

# %% [markdown]
# \begin{align*}
# \dfrac{\partial \textrm{Error}}{\partial \boldsymbol{w}} &= -\sum\limits_{i = 1}^{N} (y_{i} - \hat{y}_{i})\boldsymbol{x}_{i} \\
# \dfrac{\partial \textrm{Error}}{\partial w_{0}} &= -\sum\limits_{i = 1}^{N} (y_{i} - \hat{y}_{i})
# \end{align*}

# %%
# define the gradient functions
def gradient_w(X, y_truth, y_predicted):
    return(-np.matmul(X.T, y_truth - y_predicted))

def gradient_w0(y_truth, y_predicted):
    return(-np.sum(y_truth - y_predicted))

# %% [markdown]
# ## Algorithm Parameters

# %%
# set learning parameters
eta = 0.01
epsilon = 0.001

# %% [markdown]
# ## Parameter Initialization

# %%
# randomly initalize w and w0
np.random.seed(421)
w = np.random.uniform(low = -0.01, high = 0.01, size = (D, 1))
w0 = np.random.uniform(low = -0.01, high = 0.01, size = 1)

# %% [markdown]
# ## Iterative Algorithm

# %% [markdown]
# $\textrm{Error} = -\sum\limits_{i = 1}^{N} \left[ y_{i}\log(\hat{y}_{i}) + (1 - y_{i}) \log(1 - \hat{y}_{i}) \right]$

# %%
# learn w and w0 using gradient descent
iteration = 1
objective_values = []
while True:
    y_predicted = sigmoid(X, w, w0)

    objective_values = np.append(objective_values,
                                 -np.sum(y_truth * safelog(y_predicted) + 
                                         (1 - y_truth) * safelog(1 - y_predicted)))

    w_old = w
    w0_old = w0

    w = w - eta * gradient_w(X, y_truth, y_predicted)
    w0 = w0 - eta * gradient_w0(y_truth, y_predicted)

    if np.sqrt((w0 - w0_old)**2 + np.sum((w - w_old)**2)) < epsilon:
        break

    iteration = iteration + 1
print(w)
print(w0)
# Out:
# [[2.46001537]
#  [2.47111621]]
# [2.08280287]

# %% [markdown]
# ## Convergence

# %%
# plot objective function during iterations
plt.figure(figsize = (8, 4))
plt.plot(range(1, iteration + 1), objective_values, "k-")
plt.xlabel("Iteration")
plt.ylabel("Error")
plt.show()

# %% [markdown]
# ## Training Performance

# %%
# calculate confusion matrix
y_predicted = 1 * (y_predicted > 0.5)
confusion_matrix = pd.crosstab(y_predicted.T, y_truth.T, 
                               rownames = ["y_pred"], 
                               colnames = ["y_truth"])
print(confusion_matrix)
# Out:
# y_truth    0    1
# y_pred
# 0        179    5
# 1          1  115

# %% [markdown]
# ## Visualization

# %%
# evaluate discriminant function on a grid
x1_interval = np.linspace(-5, +5, 501)
x2_interval = np.linspace(-5, +5, 501)
x1_grid, x2_grid = np.meshgrid(x1_interval, x2_interval)
X_grid = np.vstack((x1_grid.flatten(), x2_grid.flatten())).T

discriminant_values = sigmoid(X_grid, w, w0)
discriminant_values = discriminant_values.reshape((len(x1_interval), len(x2_interval)))

plt.figure(figsize = (8, 8))
plt.plot(X[y_truth[:, 0] == 1, 0], X[y_truth[:, 0] == 1, 1], "r.", markersize = 10)
plt.plot(X[y_truth[:, 0] == 0, 0], X[y_truth[:, 0] == 0, 1], "b.", markersize = 10)
plt.plot(X[y_predicted[:, 0] != y_truth[:, 0], 0], X[y_predicted[:, 0] != y_truth[:, 0], 1],
         "ko", markersize = 12, fillstyle = "none")
plt.contour(x1_grid, x2_grid, discriminant_values, levels = [0.5], colors = "k")
plt.xlim((-5, +5))
plt.ylim((-5, +5))
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.show()
