# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
points = np.array([(1, 3), (2, 5), (4, 9)])
X = np.array([1, 3, 3])
y = np.array([1, 1, 3])

# %%
data_interval = np.linspace(start = 0, stop = 7, num = 701)


plt.figure(figsize = (10, 6))

#Plot points
plt.plot(X, y, "rx", markersize=5)
plt.plot()



plt.show()

# %% [markdown]
# ### Regression
# **Assumption**: Model is of the form g(x|$\theta$) := w0+w1*x
#
# **Goal**: Minimize MSE Error := $\sum_{i=1}^{N} (y_i - g(x_i))^2$

# %%
def model(x):
    return -1 + 2*x

# %%
def linear_regression(x, y):
    x_mean = np.mean(x)
    y_mean = np.mean(y)
    # Calculating w_1
    w_1 = np.sum((x - x_mean) * (y - y_mean)) / np.sum((x - x_mean)**2)
    # Calculating w_0
    w_0 = y_mean - w_1 * x_mean
    print("w0: "+str(w_0))
    print("w1: "+str(w_1))

    def model(x):
        return w_0 + x*w_1
    return model

# %%
model = linear_regression(X, y)
# Out:
# w0: 0.5
# w1: 0.5

# %%
def Error(x, y, model):
    for i in range(len(x)):
        print("Diff: " + str((y[i]-model(x[i]))))
    return np.sum((y-model(x))**2)

# %%
print(Error(X, y, model))
# Out:
# Diff: 0.0
# Diff: -1.0
# Diff: 1.0
# 2.0

# %%
#Plot points
plt.plot(X, y, "rx", markersize=5)
plt.plot()

#Plot model
y_vals = model(data_interval)

plt.plot(data_interval, y_vals)
plt.show()
